# %%
#Lab1
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot

import numpy as np

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display

# %%
#lab1
sin_than = thinkdsp.SinSignal(freq=7008, amp=8.0, offset=0)
sin_than.plot()
thinkplot.config(xlabel='Time (s)')

# %%
#Lab02
#3 เหลี่ยม
#TriangleSignal( คือค่า F )
#duration = signal.period*N
signal = thinkdsp.TriangleSignal(4000)
duration = signal.period*2500
segment = signal.make_wave(duration , framerate=10000)
segment.plot()
wave = signal.make_wave(duration , framerate =10000)
wave.apodize()
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 4 เหลี่ยม
signalSQ = thinkdsp.SquareSignal(4000)
duration = signalSQ.period*2500
segment = signalSQ.make_wave(duration, framerate=10000)
segment.plot()
thinkplot.config(ylim=[-1.05, 1.05], legend=False)
segment = signal.make_wave(duration , framerate =10000)
segment.apodize()
segment.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
